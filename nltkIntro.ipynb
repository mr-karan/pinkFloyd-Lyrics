# %%
import nltk
from nltk import FreqDist
import csv
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from collections import OrderedDict

# %%
with open ("lyricsAll.txt", "r") as myfile:
    text=myfile.read().replace('\n', '')

# %%
tokenizer = RegexpTokenizer(r'\w+')
nltext=nltk.Text(tokenizer.tokenize(text))

# %%
print (nltext)
# Out:
# <Text: Lime and limpid green a second scene A...>

# %%
nltext[1024:1062]
# Out:
# ['your',
#  'king',
#  'Why',
#  'can',
#  't',
#  'we',
#  'play',
#  'today',
#  'Why',
#  'can',
#  't',
#  'we',
#  'stay',
#  'that',
#  'way',
#  'Climb',
#  'your',
#  'favorite',
#  'apple',
#  'tree',
#  'Try',
#  'to',
#  'catch',
#  'the',
#  'sun',
#  'Hide',
#  'from',
#  'your',
#  'little',
#  'brother',
#  's',
#  'gun',
#  'Dream',
#  'yourself',
#  'away',
#  'Why',
#  'can',
#  't']

# %%
nltext.collocations()
# Out:
# Arnold Layne; Layne Arnold; icy waters; One world; limpid green; Ooooh
# Babe; waters underground; crazy diamond; Free games; nah nah; dark
# side; little bit; play Free; See Emily; Neptune Titan; Oberon Miranda;
# Saturn Oberon; Scream thy; Titan Stars; Titania Neptune

# %%
filtered_words=[word for word in nltext if word.lower() not in stopwords.words('english') and len(word) >=3]

# %%
print (filtered_words)
# Out:
# ['Lime', 'limpid', 'green', 'second', 'scene', 'fight', 'blue', 'knew', 'Floating', 'sound', 'resounds', 'Around', 'icy', 'waters', 'underground', 'Jupiter', 'Saturn', 'Oberon', 'Miranda', 'Titania', 'Neptune', 'Titan', 'Stars', 'frighten', 'Lime', 'limpid', 'green', 'second', 'scene', 'fight', 'blue', 'knew', 'Floating', 'sound', 'resounds', 'Around', 'icy', 'waters', 'underground', 'Jupiter', 'Saturn', 'Oberon', 'Miranda', 'Titania', 'Neptune', 'Titan', 'Stars', 'frighten', 'Blinding', 'signs', 'flap', 'Flicker', 'flicker', 'flicker', 'blam', 'Pow', 'pow', 'Stairway', 'scare', 'Dan', 'Dare', 'Lime', 'limpid', 'green', 'sounds', 'around', 'icy', 'waters', 'Lime', 'limpid', 'green', 'sounds', 'around', 'icy', 'waters', 'underground', 'Lucifer', 'Sam', 'siam', 'cat', 'Always', 'sitting', 'side', 'Always', 'side', 'cat', 'something', 'explain', 'Ginger', 'ginger', 'Jennifer', 'Gentle', 'witch', 'left', 'side', 'right', 'side', 'cat', 'something', 'explain', 'Lucifer', 'sea', 'hip', 'cat', 'ship', 'cat', 'Somewhere', 'anywhere', 'cat', 'something', 'explain', 'night', 'prowling', 'sifting', 'sand', 'Hiding', 'around', 'ground', 'found', 'around', 'cat', 'something', 'explain', 'king', 'ruled', 'land', 'majesty', 'command', 'silver', 'eyes', 'scarlet', 'eagle', 'Showers', 'silver', 'people', 'Mother', 'tell', 'leave', 'Hanging', 'infant', 'air', 'Waiting', 'read', 'lines', 'scribbly', 'black', 'everything', 'shines', 'Across', 'stream', 'wooden', 'shoes', 'bells', 'tell', 'king', 'news', 'thousand', 'misty', 'riders', 'climb', 'Higher', 'upon', 'time', 'Wandering', 'dreaming', 'words', 'different', 'meaning', 'Yes', 'time', 'spent', 'room', 'doll', 'house', 'darkness', 'old', 'perfume', 'fairy', 'sories', 'held', 'high', 'Clouds', 'sunlight', 'floating', 'Mother', 'tell', 'Tell', 'Aaaaaaaah', 'Aaaaaaaah', 'AaaaaaaahAlone', 'clouds', 'blue', 'Lying', 'eiderdown', 'Yippee', 'see', 'Lazing', 'foggy', 'dew', 'Sitting', 'unicorn', 'fair', 'hear', 'Watching', 'buttercups', 'cup', 'light', 'Sleeping', 'dandelion', 'much', 'won', 'touch', 'might', 'Screaming', 'starlit', 'sky', 'Travelling', 'telephone', 'Hey', 'Ever', 'high', 'Alone', 'clouds', 'blue', 'Lying', 'eiderdown', 'Yippee', 'see', 'Doctor', 'doctor', 'bed', 'Achin', 'head', 'Gold', 'lead', 'Choke', 'bread', 'Underfed', 'Gold', 'lead', 'Jesus', 'bled', 'Pain', 'red', 'goon', 'Grow', 'Greasy', 'spoon', 'swoon', 'June', 'bloom', 'Music', 'seems', 'help', 'pain', 'Seems', 'cultivate', 'brain', 'Doctor', 'kindly', 'tell', 'wife', 'alive', 'flowers', 'thrive', 'realize', 'realize', 'Realize', 'want', 'tell', 'story', 'little', 'man', 'gnome', 'named', 'Grimble', 'Grumble', 'little', 'gnomes', 'stay', 'homes', 'Eating', 'sleeping', 'drinking', 'wine', 'wore', 'scarlet', 'tunic', 'blue', 'green', 'hood', 'looked', 'quite', 'good', 'big', 'adventure', 'Amidst', 'grass', 'Fresh', 'air', 'last', 'Wining', 'dining', 'biding', 'time', 'one', 'day', 'hooray', 'Another', 'way', 'gnomes', 'say', 'Hoooooooooray', 'Look', 'sky', 'look', 'river', 'Isn', 'good', 'Look', 'sky', 'look', 'river', 'Isn', 'good', 'Winding', 'finding', 'places', 'one', 'day', 'hooray', 'Another', 'way', 'gnomes', 'say', 'Hoooooooooray', 'Hooooooooooooooray', 'movement', 'accomplished', 'six', 'stages', 'seventh', 'brings', 'return', 'seven', 'number', 'young', 'light', 'forms', 'darkness', 'increased', 'one', 'Change', 'returns', 'success', 'Going', 'coming', 'without', 'error', 'Action', 'brings', 'good', 'fortune', 'Sunset', 'time', 'month', 'winter', 'solstice', 'change', 'due', 'come', 'Thunder', 'course', 'heaven', 'Things', 'cannot', 'destroyed', 'Change', 'returns', 'success', 'Going', 'coming', 'without', 'error', 'Action', 'brings', 'good', 'fortune', 'Sunset', 'sunrise', 'movement', 'accomplished', 'six', 'stages', 'seventh', 'brings', 'return', 'seven', 'number', 'young', 'light', 'forms', 'darkness', 'increased', 'one', 'Change', 'returns', 'success', 'Going', 'coming', 'without', 'error', 'Action', 'brings' ...

# %%
commonText=nltk.Text(filtered_words)

# %%
commonText
# Out:
# <Text: Lime limpid green second scene fight blue knew...>

# %%
freq=FreqDist(commonText)

# %%
visualize=(freq.most_common(25))

# %%
dV=dict(visualize)

# %%
finalData=OrderedDict(sorted(dV.items(), key=lambda t: t[1],reverse=True))

# %%
print (finalData)
# Out:
# OrderedDict([('time', 63), ('day', 60), ('sun', 58), ('like', 58), ('know', 55), ('one', 55), ('way', 52), ('make', 52), ('away', 44), ('would', 44), ('get', 44), ('man', 44), ('got', 42), ('eyes', 41), ('good', 41), ('see', 41), ('night', 37), ('heart', 36), ('say', 34), ('little', 33), ('need', 33), ('sky', 32), ('hear', 32), ('home', 31), ('think', 31)])

# %%
writer = csv.writer(open('visual.csv', 'a'))
for key, value in finalData.items():
   writer.writerow([key, value])
